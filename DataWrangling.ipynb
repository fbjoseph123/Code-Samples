# %%
import pandas as pd
import sodapy
from sodapy import Socrata 
import os
base_path = r'C:\Users\frank\OneDrive\Documents\GitHub\final-project-fbjoseph123'
client = Socrata('chronicdata.cdc.gov', None)
results = client.get("swc5-untb")
places_data = pd.DataFrame.from_records(results)
path = os.path.join(base_path,'SVI2020_US.csv')
SVI_data = pd.read_csv(path)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
places_data.head()
# Out:
#    year stateabbr statedesc locationname datasource               category  \
# 0  2020        WY   Wyoming  Hot Springs      BRFSS        Health Outcomes
# 1  2020        WY   Wyoming     Sheridan      BRFSS        Health Outcomes
# 2  2019        WY   Wyoming     Big Horn      BRFSS             Prevention
# 3  2020        WY   Wyoming      Natrona      BRFSS  Health Risk Behaviors
# 4  2020        WY   Wyoming         Park      BRFSS  Health Risk Behaviors
#
#                                              measure data_value_unit  \
# 0  Coronary heart disease among adults aged >=18 ...               %
# 1             Arthritis among adults aged >=18 years               %
# 2  Taking medicine for high blood pressure contro...               %
# 3  No leisure-time physical activity among adults...               %
# 4  No leisure-time physical activity among adults...               %
#
#            data_value_type data_value  ... high_confidence_limit  \
# 0  Age-adjusted prevalence        6.0  ...                   6.6
# 1         Crude prevalence       25.0  ...                  26.3
# 2         Crude prevalence       76.9  ...                  78.0
# 3  Age-adjusted prevalence       25.0  ...                  27.5
# 4  Age-adjusted prevalence       20.8  ...                  23.3
#
#   totalpopulation locationid categoryid  measureid datavaluetypeid  \
# 0            4425      56017    HLTHOUT        CHD       AgeAdjPrv
# 1           30863      56033    HLTHOUT  ARTHRITIS          CrdPrv
# 2           11575      56003    PREVENT      BPMED          CrdPrv
# 3           80815      56025    RISKBEH        LPA       AgeAdjPrv
# 4           29331      56029    RISKBEH        LPA       AgeAdjPrv
#
#       short_question_text                                        geolocation  \
# 0  Coronary Heart Disease  {'type': 'Point', 'coordinates': [-108.4350765...
# 1               Arthritis  {'type': 'Point', 'coordinates': [-106.8812114...
# 2    Taking BP Medication  {'type': 'Point', 'coordinates': [-107.9948477...
# 3     Physical Inactivity  {'type': 'Point', 'coordinates': [-106.7682192...
# 4     Physical Inactivity  {'type': 'Point', 'coordinates': [-109.5935975...
#
#   :@computed_region_bxsw_vy29 :@computed_region_he4y_prf8
# 0                          14                        3117
# 1                          14                        3123
# 2                          14                        3080
# 3                          14                         891
# 4                          14                        3122
#
# [5 rows x 21 columns]
